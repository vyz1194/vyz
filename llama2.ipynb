# %% [markdown]
# <a href="https://colab.research.google.com/github/vyz1194/vyz/blob/master/llama2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade huggingface_hub
# !pip install transformers==4.30.2
# !pip install accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 trl==0.4.7
# !pip install sentencepiece
# !pip install petals
# Out:
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.7.22)
# Installing collected packages: huggingface_hub
# Successfully installed huggingface_hub-0.16.4
# Collecting transformers==4.30.2
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 28.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.30.2)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 85.0 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers==4.30.2)
#   Downloading safetensors-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.2) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.2) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, transformers
# Successfully installed safetensors-0.3.2 tokenizers-0.13.3 transformers-4.30.2
# Collecting accelerate==0.21.0
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 4.2 MB/s eta 0:00:00
# Collecting peft==0.4.0
#   Downloading peft-0.4.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 8.4 MB/s eta 0:00:00
# Collecting bitsandbytes==0.40.2
#   Downloading bitsandbytes-0.40.2-py3-none-any.whl (92.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 9.1 MB/s eta 0:00:00
# Collecting trl==0.4.7
#   Downloading trl-0.4.7-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0) (2.0.1+cu118)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft==0.4.0) (4.30.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft==0.4.0) (0.3.2)
# Collecting datasets (from trl==0.4.7)
#   Downloading datasets-2.14.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 48.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.21.0) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.21.0) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.21.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.21.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.21.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.21.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate==0.21.0) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate==0.21.0) (16.0.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.4.0) (0.16.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.4.0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.4.0) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.4.0) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.4.0) (4.66.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.4.7) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->trl==0.4.7)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.4.7) (1.5.3)
# Collecting xxhash (from datasets->trl==0.4.7)
#   Downloading xxhash-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.8 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->trl==0.4.7)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.4.7) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.4.7) (3.8.5)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.4.7) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.4.7) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.4.7) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.4.7) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.4.7) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.4.7) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.4.7) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft==0.4.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft==0.4.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft==0.4.0) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate==0.21.0) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl==0.4.7) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl==0.4.7) (2023.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate==0.21.0) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->trl==0.4.7) (1.16.0)
# Installing collected packages: bitsandbytes, xxhash, dill, multiprocess, datasets, accelerate, trl, peft
# Successfully installed accelerate-0.21.0 bitsandbytes-0.40.2 datasets-2.14.4 dill-0.3.7 multiprocess-0.70.15 peft-0.4.0 trl-0.4.7 xxhash-3.3.0
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.5 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99
# Collecting petals
#   Downloading petals-2.0.1.post2-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.8/105.8 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.10/dist-packages (from petals) (2.0.1+cu118)
# Collecting bitsandbytes==0.41.1 (from petals)
#   Downloading bitsandbytes-0.41.1-py3-none-any.whl (92.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.1 MB/s eta 0:00:00
# Collecting accelerate<0.21.0,>=0.20.3 (from petals)
#   Downloading accelerate-0.20.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 26.0 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from petals) (0.16.4)
# Requirement already satisfied: tokenizers>=0.13.3 in /usr/local/lib/python3.10/dist-packages (from petals) (0.13.3)
# Collecting transformers<5.0.0,>=4.31.0 (from petals)
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 109.2 MB/s eta 0:00:00
# Collecting speedtest-cli==2.1.3 (from petals)
#   Downloading speedtest_cli-2.1.3-py2.py3-none-any.whl (23 kB)
# Collecting pydantic<2.0,>=1.10 (from petals)
#   Downloading pydantic-1.10.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 67.7 MB/s eta 0:00:00
# Collecting hivemind==1.1.9 (from petals)
#   Downloading hivemind-1.1.9-py3-none-any.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 79.9 MB/s eta 0:00:00
# Collecting tensor-parallel==1.0.23 (from petals)
#   Downloading tensor_parallel-1.0.23-py3-none-any.whl (25 kB)
# Collecting humanfriendly (from petals)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from petals) (4.0.3)
# Collecting cpufeature>=0.2.0 (from petals)
#   Downloading cpufeature-0.2.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from petals) (23.1)
# Requirement already satisfied: sentencepiece>=0.1.99 in /usr/local/lib/python3.10/dist-packages (from petals) (0.1.99)
# Requirement already satisfied: peft>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from petals) (0.4.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from petals) (0.3.2)
# Collecting Dijkstar>=2.6.0 (from petals)
#   Downloading Dijkstar-2.6.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (6.0.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (1.23.5)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (1.10.1)
# Requirement already satisfied: prefetch-generator>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (1.0.3)
# Requirement already satisfied: msgpack>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (1.0.5)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (2.4.0)
# Collecting uvloop>=0.14.0 (from hivemind==1.1.9->petals)
#   Downloading uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 65.6 MB/s eta 0:00:00
# Collecting grpcio-tools>=1.33.2 (from hivemind==1.1.9->petals)
#   Downloading grpcio_tools-1.57.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 64.2 MB/s eta 0:00:00
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (3.20.3)
# Collecting configargparse>=1.2.3 (from hivemind==1.1.9->petals)
#   Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Collecting multiaddr>=0.0.9 (from hivemind==1.1.9->petals)
#   Downloading multiaddr-0.0.9-py2.py3-none-any.whl (16 kB)
# Collecting pymultihash>=0.8.2 (from hivemind==1.1.9->petals)
#   Downloading pymultihash-0.8.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: cryptography>=3.4.6 in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (41.0.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate<0.21.0,>=0.20.3->petals) (5.9.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from Dijkstar>=2.6.0->petals) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.1->petals) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.1->petals) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.1->petals) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.1->petals) (4.66.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.1->petals) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->petals) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->petals) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->petals) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->petals) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.12->petals) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.12->petals) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.31.0->petals) (2023.6.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.4.6->hivemind==1.1.9->petals) (1.15.1)
# Collecting protobuf>=3.12.2 (from hivemind==1.1.9->petals)
#   Downloading protobuf-4.24.0-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.57.0 in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.33.2->hivemind==1.1.9->petals) (1.57.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.33.2->hivemind==1.1.9->petals) (67.7.2)
# Collecting varint (from multiaddr>=0.0.9->hivemind==1.1.9->petals)
#   Downloading varint-1.0.2.tar.gz (1.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting base58 (from multiaddr>=0.0.9->hivemind==1.1.9->petals)
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting netaddr (from multiaddr>=0.0.9->hivemind==1.1.9->petals)
#   Downloading netaddr-0.8.0-py2.py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 91.7 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12->petals) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.11.1->petals) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.11.1->petals) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.11.1->petals) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.11.1->petals) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12->petals) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.4.6->hivemind==1.1.9->petals) (2.21)
# Building wheels for collected packages: varint
#   Building wheel for varint (setup.py) ... done
#   Created wheel for varint: filename=varint-1.0.2-py3-none-any.whl size=1962 sha256=5f7b0084640741d203d60a985a5a2d9d835edd9e082f7f0ba047ba7e981157a2
#   Stored in directory: /root/.cache/pip/wheels/39/48/5e/33919c52a2a695a512ca394a5308dd12626a40bbcd288de814
# Successfully built varint
# Installing collected packages: varint, speedtest-cli, pymultihash, netaddr, cpufeature, bitsandbytes, uvloop, pydantic, protobuf, humanfriendly, Dijkstar, configargparse, base58, multiaddr, grpcio-tools, transformers, accelerate, tensor-parallel, hivemind, petals
#   Attempting uninstall: bitsandbytes
#     Found existing installation: bitsandbytes 0.40.2
#     Uninstalling bitsandbytes-0.40.2:
#       Successfully uninstalled bitsandbytes-0.40.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.1.1
#     Uninstalling pydantic-2.1.1:
#       Successfully uninstalled pydantic-2.1.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.30.2
#     Uninstalling transformers-4.30.2:
#       Successfully uninstalled transformers-4.30.2
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.21.0
#     Uninstalling accelerate-0.21.0:
#       Successfully uninstalled accelerate-0.21.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.24.0 which is incompatible.
# Successfully installed Dijkstar-2.6.0 accelerate-0.20.3 base58-2.1.1 bitsandbytes-0.41.1 configargparse-1.7 cpufeature-0.2.1 grpcio-tools-1.57.0 hivemind-1.1.9 humanfriendly-10.0 multiaddr-0.0.9 netaddr-0.8.0 petals-2.0.1.post2 protobuf-4.24.0 pydantic-1.10.12 pymultihash-0.8.2 speedtest-cli-2.1.3 tensor-parallel-1.0.23 transformers-4.31.0 uvloop-0.17.0 varint-1.0.2

# %%
#Fine Tuning Reference https://medium.com/@jain.sm/finetuning-llama-2-0-on-colab-with-1-gpu-7ea73a8d3db9

# %%
#Token : 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

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
import torch
from transformers import AutoTokenizer
from petals import AutoDistributedModelForCausalLM

model_name = "meta-llama/Llama-2-70b-chat-hf"

tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=False, add_bos_token=False)
model = AutoDistributedModelForCausalLM.from_pretrained(model_name)
model = model.cuda()
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Aug 16 14:25:52.640 [INFO] Make sure you follow the LLaMA's terms of use: https://bit.ly/llama2-license for LLaMA 2, https://bit.ly/llama-license for LLaMA 1
# Aug 16 14:25:52.645 [INFO] Using DHT prefix: Llama-2-70b-chat-hf
# Downloading (…)fetensors.index.json:   0%|          | 0.00/66.7k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading (…)of-00015.safetensors:   0%|          | 0.00/9.85G [00:00<?, ?B/s]
# Downloading (…)of-00015.safetensors:   0%|          | 0.00/9.50G [00:00<?, ?B/s]
# Downloading (…)of-00015.safetensors:   0%|          | 0.00/524M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
#model_name = "stabilityai/StableBeluga2"
# You could also use "meta-llama/Llama-2-70b-chat-hf" or any other supported model from 🤗 Model Hub

#tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=False, add_bos_token=False)
#model = AutoDistributedModelForCausalLM.from_pretrained(model_name)
#model = model.cuda()

# %%
inputs = tokenizer('Can you plan activities to do for a 5 day trip to Paris? Answer:"', return_tensors="pt")["input_ids"].cuda()
outputs = model.generate(inputs, max_new_tokens=200)
print(tokenizer.decode(outputs[0]))
# Out:
# Aug 16 14:31:14.566 [INFO] Route found: 0:20 via …RPFSct => 20:46 via …kDJVjh => 46:66 via …MWaAxr => 66:80 via …rgNAo9
# Can you plan activities to do for a 5 day trip to Paris? Answer:"Bonjour! Certainly, I'd be happy to help you plan activities for your 5-day trip to Paris. Here's a sample itinerary that includes a mix of popular attractions, cultural experiences, and delicious food: Day 1: Arrival and Exploring Montmartre Start your trip by checking into your accommodation and taking a stroll around the charming neighborhood of Montmartre. Visit the iconic Sacré-Cœur Basilica and enjoy the panoramic views of the city from its steps. Wander through the narrow streets and alleys, stopping for coffee or a snack at a charming café. In the evening, enjoy a traditional French dinner at a nearby restaurant. Day 2: Parisian Landmarks Begin your day at the famous Café de Flore or Les Deux Magots, where you can enjoy a coffee and people-watch. Then, head to the Luxembourg

# %%
outputs
# Out:
# tensor([[ 1815,   366,  3814, 14188,   304,   437,   363,   263, 29871, 29945,
#           2462, 17487,   304,  3681, 29973,   673,  6160, 29933,   265, 29926,
#            473, 29991,   315, 13946,   368, 29892,   306, 29915, 29881,   367,
#           9796,   304,  1371,   366,  3814, 14188,   363,   596, 29871, 29945,
#          29899,  3250, 17487,   304,  3681, 29889,  2266, 29915, 29879,   263,
#           4559,   372,  4983,   653,   393,  7805,   263,  6837,   310,  5972,
#          19650,  1953, 29892, 16375, 27482, 29892,   322,   628, 14803,  9687,
#          29901,  8373, 29871, 29896, 29901,   826, 15081,   322,  1222,   572,
#           8253,  4526, 28402,   276,  7370,   596, 17487,   491,  8454,   964,
#            596, 24803,   362,   322,  5622,   263,   380,  1245,  2820,   278,
#           1373,  4056, 18403,   310,  4526, 28402,   276, 29889,  5741,   277,
#            278,  9849,   293, 15573,  5606, 29899, 29907, 16581,  4886,   309,
#            983,   322, 13389,   278,  7243,   272,   314,   293,  8386,   310,
#            278,  4272,   515,   967,  6576, 29889,   399,  3825,  1549,   278,
#          12474, 19756,   322,  4788,   952, 29892, 25480,   363, 26935,   470,
#            263,  5807,   547,   472,   263,  1373,  4056,   274, 28059, 29889,
#            512,   278, 11005, 29892, 13389,   263, 13807,  5176, 17803,   472,
#            263, 20810, 27144, 29889,  8373, 29871, 29906, 29901,  3681,   713,
#           3172, 22848, 14893,   596,  2462,   472,   278, 13834,   315, 28059,
#            316,  2379,   487,   470,  2664, 26079,  3561,  1862, 29892,   988,
#            366,   508, 13389,   263, 26935,   322,  2305, 29899, 12344, 29889,
#           1987, 29892,  2343,   304,   278, 23812, 18041]], device='cuda:0')

# %%
inputs = tokenizer('Can you plan activities to do for a 5 day trip to Paris? Answer:"', return_tensors="pt")["input_ids"].cuda()
outputs = model.generate(inputs, max_new_tokens=400)
print(tokenizer.decode(outputs[0]))
# Out:
# Aug 16 14:34:32.489 [INFO] Route found: 0:20 via …RPFSct => 20:46 via …kDJVjh => 46:66 via …MWaAxr => 66:80 via …rgNAo9
# Can you plan activities to do for a 5 day trip to Paris? Answer:"Bonjour! Certainly, I'd be happy to help you plan activities for your 5-day trip to Paris. Here's a sample itinerary that includes a mix of popular attractions, cultural experiences, and delicious food: Day 1: Arrival and Exploring Montmartre Start your trip by checking into your accommodation and taking a stroll around the charming neighborhood of Montmartre. Visit the iconic Sacré-Cœur Basilica and enjoy the panoramic views of the city from its steps. Wander through the narrow streets and alleys, stopping for coffee or a snack at a charming café. In the evening, enjoy a traditional French dinner at a nearby restaurant. Day 2: Parisian Landmarks Begin your day at the famous Café de Flore or Les Deux Magots, where you can enjoy a coffee and people-watch. Then, head to the Luxembourg Gardens for a leisurely stroll. Afterward, visit the nearby Saint-Germain-des-Prés neighborhood and explore its high-end boutiques and art galleries. End your day with a visit to the Eiffel Tower, either for a sunset view or a romantic dinner at the Michelin-starred restaurant, Le Jules Verne. Day 3: Museums and Culture Spend the morning exploring the Louvre Museum and admiring famous works of art such as the Mona Lisa and Venus de Milo. In the afternoon, visit the Musée d'Orsay to see an impressive collection of Impressionist and Post-Impressionist art. End your day with a visit to the Palais Garnier, a stunning opera house with opulent decorations and a rich history. Day 4: Day Trip to Versailles Take a day trip to the Palace of Versailles,

# %%
inputs = tokenizer('Could you tells us some instreing facts about Paris? Answer:"', return_tensors="pt")["input_ids"].cuda()
outputs = model.generate(inputs, max_new_tokens=500)
print(tokenizer.decode(outputs[0]))
# Out:
# Aug 16 14:41:02.877 [INFO] Route found: 0:20 via …RPFSct => 20:46 via …kDJVjh => 46:66 via …MWaAxr => 66:80 via …rgNAo9
# Could you tells us some instreing facts about Paris? Answer:"Paris, the capital of France, is known as the City of Light and is famous for its stunning architecture, art museums, fashion, cuisine, and romantic atmosphere. Here are some interesting facts about Paris:
# 1. Paris has a network of underground tunnels and passageways called the "Catacombs of Paris." These tunnels were built in the 18th century and stretch for over 150 miles.
# 2. The Eiffel Tower was originally intended to be a temporary structure, built for the 1889 World's Fair. It was meant to be dismantled after the fair, but it became an instant icon of Paris and was left standing.
# 3. The Louvre Museum was once a royal palace, and the building's original moat still exists underneath the museum. Visitors can take a guided tour of the moat, which is now home to many artifacts and artworks.
# 4. Paris has a secret underground river, called the "River Biévre." The river was once used for transportation and industry, but it was covered over in the 19th century and is now mostly forgotten.
# 5. The famous Notre-Dame Cathedral has a unique architectural feature: its Gothic arches are supported by "flying buttresses," which are arches that spring from the walls and support the roof. This design allows the building to have larger windows and a more open interior.
# 6. The Champs-Élysées, one of Paris's most famous streets, was once a field of cabbage. The street was named after the Elysian Fields of Greek mythology, which were a place of paradise for heroes and virtuous individuals.
# 7. The Montmartre neighborhood, known for its bohemian vibe and street artists, was once a separate village from Paris. It was incorporated into the city in 1860.
# 8. The famous Parisian landmark, the Arc de Triomphe, has a secret apartment built into its structure. The apartment was originally designed for Napoleon, but he never got to use it. It has been off-limits to visitors for many years, but it is now possible to visit the apartment on a guided tour.
# 9. Paris has a g
