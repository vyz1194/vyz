# %% [markdown]
# <a href="https://colab.research.google.com/github/vyz1194/vyz/blob/master/llama2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade huggingface_hub
# !pip install transformers==4.30.2
# !pip install accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 trl==0.4.7
# !pip install sentencepiece
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.16.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (23.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4)
# Collecting transformers==4.30.2
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 20.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.30.2)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 87.8 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers==4.30.2)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.2) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.2) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.2) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.2) (3.4)
# Installing collected packages: tokenizers, safetensors, transformers
# Successfully installed safetensors-0.3.1 tokenizers-0.13.3 transformers-4.30.2
# Collecting accelerate==0.21.0
#   Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 4.8 MB/s eta 0:00:00
# Collecting peft==0.4.0
#   Downloading peft-0.4.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 6.8 MB/s eta 0:00:00
# Collecting bitsandbytes==0.40.2
#   Downloading bitsandbytes-0.40.2-py3-none-any.whl (92.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 9.2 MB/s eta 0:00:00
# Collecting trl==0.4.7
#   Downloading trl-0.4.7-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0) (23.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.21.0) (2.0.1+cu118)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft==0.4.0) (4.30.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft==0.4.0) (0.3.1)
# Collecting datasets (from trl==0.4.7)
#   Downloading datasets-2.14.3-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.1/519.1 kB 55.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.21.0) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.21.0) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.21.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.21.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.21.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.21.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate==0.21.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate==0.21.0) (16.0.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.4.0) (0.16.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.4.0) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.4.0) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.4.0) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->peft==0.4.0) (4.65.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.4.7) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->trl==0.4.7)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.4.7) (1.5.3)
# Collecting xxhash (from datasets->trl==0.4.7)
#   Downloading xxhash-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 26.5 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->trl==0.4.7)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.4.7) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->trl==0.4.7) (3.8.5)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.4.7) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.4.7) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.4.7) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.4.7) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.4.7) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.4.7) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl==0.4.7) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft==0.4.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft==0.4.0) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft==0.4.0) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate==0.21.0) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl==0.4.7) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl==0.4.7) (2022.7.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate==0.21.0) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->trl==0.4.7) (1.16.0)
# Installing collected packages: bitsandbytes, xxhash, dill, multiprocess, datasets, accelerate, trl, peft
# Successfully installed accelerate-0.21.0 bitsandbytes-0.40.2 datasets-2.14.3 dill-0.3.7 multiprocess-0.70.15 peft-0.4.0 trl-0.4.7 xxhash-3.3.0
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.7 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
Remaining after downloading LLAMA 2 https://medium.com/@jain.sm/finetuning-llama-2-0-on-colab-with-1-gpu-7ea73a8d3db9

# %%
# !pip install petals
# Out:
# Collecting petals
#   Downloading petals-2.0.1.post1-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.10/dist-packages (from petals) (2.0.1+cu118)
# Collecting bitsandbytes==0.40.1.post1 (from petals)
#   Downloading bitsandbytes-0.40.1.post1-py3-none-any.whl (93.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 MB 9.2 MB/s eta 0:00:00
# Collecting accelerate<0.21.0,>=0.20.3 (from petals)
#   Downloading accelerate-0.20.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 kB 26.1 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.11.1 (from petals)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 33.7 MB/s eta 0:00:00
# Collecting tokenizers>=0.13.3 (from petals)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 96.3 MB/s eta 0:00:00
# Collecting transformers<5.0.0,>=4.31.0 (from petals)
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 99.0 MB/s eta 0:00:00
# Collecting speedtest-cli==2.1.3 (from petals)
#   Downloading speedtest_cli-2.1.3-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pydantic<2.0,>=1.10 in /usr/local/lib/python3.10/dist-packages (from petals) (1.10.12)
# Collecting hivemind==1.1.9 (from petals)
#   Downloading hivemind-1.1.9-py3-none-any.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 63.3 MB/s eta 0:00:00
# Collecting tensor-parallel==1.0.23 (from petals)
#   Downloading tensor_parallel-1.0.23-py3-none-any.whl (25 kB)
# Collecting humanfriendly (from petals)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from petals) (4.0.2)
# Collecting cpufeature>=0.2.0 (from petals)
#   Downloading cpufeature-0.2.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from petals) (23.1)
# Collecting sentencepiece>=0.1.99 (from petals)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.7 MB/s eta 0:00:00
# Collecting peft>=0.4.0 (from petals)
#   Downloading peft-0.4.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 13.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from petals)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 55.7 MB/s eta 0:00:00
# Collecting Dijkstar>=2.6.0 (from petals)
#   Downloading Dijkstar-2.6.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (6.0.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (1.22.4)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (1.10.1)
# Requirement already satisfied: prefetch-generator>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (1.0.3)
# Requirement already satisfied: msgpack>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (1.0.5)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (2.4.0)
# Collecting uvloop>=0.14.0 (from hivemind==1.1.9->petals)
#   Downloading uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 106.1 MB/s eta 0:00:00
# Collecting grpcio-tools>=1.33.2 (from hivemind==1.1.9->petals)
#   Downloading grpcio_tools-1.56.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 46.2 MB/s eta 0:00:00
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.10/dist-packages (from hivemind==1.1.9->petals) (3.20.3)
# Collecting configargparse>=1.2.3 (from hivemind==1.1.9->petals)
#   Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Collecting multiaddr>=0.0.9 (from hivemind==1.1.9->petals)
#   Downloading multiaddr-0.0.9-py2.py3-none-any.whl (16 kB)
# Collecting pymultihash>=0.8.2 (from hivemind==1.1.9->petals)
#   Downloading pymultihash-0.8.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: cryptography>=3.4.6 in /usr/lib/python3/dist-packages (from hivemind==1.1.9->petals) (3.4.8)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate<0.21.0,>=0.20.3->petals) (5.9.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from Dijkstar>=2.6.0->petals) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.1->petals) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.1->petals) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.1->petals) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.1->petals) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.1->petals) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->petals) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->petals) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->petals) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->petals) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.12->petals) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.12->petals) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.31.0->petals) (2022.10.31)
# Collecting protobuf>=3.12.2 (from hivemind==1.1.9->petals)
#   Downloading protobuf-4.23.4-cp37-abi3-manylinux2014_x86_64.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 37.5 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.33.2->hivemind==1.1.9->petals) (1.56.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.33.2->hivemind==1.1.9->petals) (67.7.2)
# Collecting varint (from multiaddr>=0.0.9->hivemind==1.1.9->petals)
#   Downloading varint-1.0.2.tar.gz (1.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting base58 (from multiaddr>=0.0.9->hivemind==1.1.9->petals)
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting netaddr (from multiaddr>=0.0.9->hivemind==1.1.9->petals)
#   Downloading netaddr-0.8.0-py2.py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 89.2 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12->petals) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.11.1->petals) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.11.1->petals) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.11.1->petals) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub<1.0.0,>=0.11.1->petals) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.12->petals) (1.3.0)
# Building wheels for collected packages: varint
#   Building wheel for varint (setup.py) ... done
#   Created wheel for varint: filename=varint-1.0.2-py3-none-any.whl size=1962 sha256=f3d1702b7420e6786dba4fd55bbaead4dd23c3ec7bad3da2da7d1fb1d9ab4beb
#   Stored in directory: /root/.cache/pip/wheels/39/48/5e/33919c52a2a695a512ca394a5308dd12626a40bbcd288de814
# Successfully built varint
# Installing collected packages: varint, tokenizers, speedtest-cli, sentencepiece, safetensors, pymultihash, netaddr, cpufeature, bitsandbytes, uvloop, protobuf, humanfriendly, Dijkstar, configargparse, base58, multiaddr, huggingface-hub, grpcio-tools, transformers, accelerate, tensor-parallel, peft, hivemind, petals
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed Dijkstar-2.6.0 accelerate-0.20.3 base58-2.1.1 bitsandbytes-0.40.1.post1 configargparse-1.7 cpufeature-0.2.1 grpcio-tools-1.56.2 hivemind-1.1.9 huggingface-hub-0.16.4 humanfriendly-10.0 multiaddr-0.0.9 netaddr-0.8.0 peft-0.4.0 petals-2.0.1.post1 protobuf-4.23.4 pymultihash-0.8.2 safetensors-0.3.1 sentencepiece-0.1.99 speedtest-cli-2.1.3 tensor-parallel-1.0.23 tokenizers-0.13.3 transformers-4.31.0 uvloop-0.17.0 varint-1.0.2

# %%
import torch
from transformers import AutoTokenizer
from petals import AutoDistributedModelForCausalLM

model_name = "meta-llama/Llama-2-70b-chat-hf"#"stabilityai/StableBeluga2"
# You could also use "meta-llama/Llama-2-70b-chat-hf" or any other supported model from 🤗 Model Hub

tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=False, add_bos_token=False)
model = AutoDistributedModelForCausalLM.from_pretrained(model_name)
model = model.cuda()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py:261 in                  │
# │ hf_raise_for_status                                                                              │
# │                                                                                                  │
# │   258 │   </Tip>                                                                                 │
# │   259 │   """                                                                                    │
# │   260 │   try:                                                                                   │
# │ ❱ 261 │   │   response.raise_for_status()                                                        │
# │   262 │   except HTTPError as e:                                                                 │
# │   263 │   │   error_code = response.headers.get("X-Error-Code")                                  │
# │   264                                                                                            │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/requests/models.py:960 in raise_for_status               │
# │                                                                                                  │
# │   957 │   │   │   http_error_msg = u'%s Server Error: %s for url: %s' % (self.status_code, rea   │
# │   958 │   │                                                                                      │
# │   959 │   │   if http_error_msg:                                                                 │
# │ ❱ 960 │   │   │   raise HTTPError(http_error_msg, response=self)                                 │
# │   961 │                                                                                          │
# │   962 │   def close(self):                                                                       │
# │   963 │   │   """Releases the connection back to the pool. Once this method has been             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# HTTPError: 401 Client Error: Unauthorized for url:
# https://huggingface.co/meta-llama/Llama-2-70b-chat-hf/resolve/main/tokenizer_config.json
#
# The above exception was the direct cause of the following exception:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:417 in cached_file             │
# │                                                                                                  │
# │    414 │   user_agent = http_user_agent(user_agent)                                              │
# │    415 │   try:                                                                                  │
# │    416 │   │   # Load from URL or cache if already cached                                        │
# │ ❱  417 │   │   resolved_file = hf_hub_download(                                                  │
# │    418 │   │   │   path_or_repo_id,                                                              │
# │    419 │   │   │   filename,                                                                     │
# │    420 │   │   │   subfolder=None if len(subfolder) == 0 else subfolder,                         │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py:118 in _inner_fn    │
# │                                                                                                  │
# │   115 │   │   if check_use_auth_token:                                                           │
# │   116 │   │   │   kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=ha   │
# │   117 │   │                                                                                      │
# │ ❱ 118 │   │   return fn(*args, **kwargs)                                                         │
# │   119 │                                                                                          │
# │   120 │   return _inner_fn  # type: ignore                                                       │
# │   121                                                                                            │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1195 in hf_hub_download │
# │                                                                                                  │
# │   1192 │   if not local_files_only:                                                              │
# │   1193 │   │   try:                                                                              │
# │   1194 │   │   │   try:                                                                          │
# │ ❱ 1195 │   │   │   │   metadata = get_hf_file_metadata(                                          │
# │   1196 │   │   │   │   │   url=url,                                                              │
# │   1197 │   │   │   │   │   token=token,                                                          │
# │   1198 │   │   │   │   │   proxies=proxies,                                                      │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py:118 in _inner_fn    │
# │                                                                                                  │
# │   115 │   │   if check_use_auth_token:                                                           │
# │   116 │   │   │   kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=ha   │
# │   117 │   │                                                                                      │
# │ ❱ 118 │   │   return fn(*args, **kwargs)                                                         │
# │   119 │                                                                                          │
# │   120 │   return _inner_fn  # type: ignore                                                       │
# │   121                                                                                            │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1541 in                 │
# │ get_hf_file_metadata                                                                             │
# │                                                                                                  │
# │   1538 │   │   proxies=proxies,                                                                  │
# │   1539 │   │   timeout=timeout,                                                                  │
# │   1540 │   )                                                                                     │
# │ ❱ 1541 │   hf_raise_for_status(r)                                                                │
# │   1542 │                                                                                         │
# │   1543 │   # Return                                                                              │
# │   1544 │   return HfFileMetadata(                                                                │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py:277 in                  │
# │ hf_raise_for_status                                                                              │
# │                                                                                                  │
# │   274 │   │   │   message = (                                                                    │
# │   275 │   │   │   │   f"{response.status_code} Client Error." + "\n\n" + f"Cannot access gated   │
# │   276 │   │   │   )                                                                              │
# │ ❱ 277 │   │   │   raise GatedRepoError(message, response) from e                                 │
# │   278 │   │                                                                                      │
# │   279 │   │   elif error_code == "RepoNotFound" or response.status_code == 401:                  │
# │   280 │   │   │   # 401 is misleading as it is returned for:                                     │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# GatedRepoError: 401 Client Error. (Request ID:
# Root=1-64cbe2e2-58b35a460136700c35b99bd4;02282055-2bc0-4ab2-96a8-b204ab718f75)
#
# Cannot access gated repo for url
# https://huggingface.co/meta-llama/Llama-2-70b-chat-hf/resolve/main/tokenizer_config.json.
# Repo model meta-llama/Llama-2-70b-chat-hf is gated. You must be authenticated to access it.
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 8>:8                                                                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:652 in     │
# │ from_pretrained                                                                                  │
# │                                                                                                  │
# │   649 │   │   │   return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *input   │
# │   650 │   │                                                                                      │
# │   651 │   │   # Next, let's try to use the tokenizer_config file to get the tokenizer class.     │
# │ ❱ 652 │   │   tokenizer_config = get_tokenizer_config(pretrained_model_name_or_path, **kwargs)   │
# │   653 │   │   if "_commit_hash" in tokenizer_config:                                             │
# │   654 │   │   │   kwargs["_commit_hash"] = tokenizer_config["_commit_hash"]                      │
# │   655 │   │   config_tokenizer_class = tokenizer_config.get("tokenizer_class")                   │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:496 in     │
# │ get_tokenizer_config                                                                             │
# │                                                                                                  │
# │   493 │   tokenizer_config = get_tokenizer_config("tokenizer-test")                              │
# │   494 │   ```"""                                                                                 │
# │   495 │   commit_hash = kwargs.get("_commit_hash", None)                                         │
# │ ❱ 496 │   resolved_config_file = cached_file(                                                    │
# │   497 │   │   pretrained_model_name_or_path,                                                     │
# │   498 │   │   TOKENIZER_CONFIG_FILE,                                                             │
# │   499 │   │   cache_dir=cache_dir,                                                               │
# │                                                                                                  │
# │ /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:433 in cached_file             │
# │                                                                                                  │
# │    430 │   │   )                                                                                 │
# │    431 │                                                                                         │
# │    432 │   except RepositoryNotFoundError:                                                       │
# │ ❱  433 │   │   raise EnvironmentError(                                                           │
# │    434 │   │   │   f"{path_or_repo_id} is not a local folder and is not a valid model identifie  │
# │    435 │   │   │   "listed on 'https://huggingface.co/models'\nIf this is a private repository,  │
# │    436 │   │   │   "pass a token having permission to this repo with `use_auth_token` or log in  │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# OSError: meta-llama/Llama-2-70b-chat-hf is not a local folder and is not a valid model identifier listed on
# 'https://huggingface.co/models'
# If this is a private repository, make sure to pass a token having permission to this repo with `use_auth_token` or
# log in with `huggingface-cli login` and pass `use_auth_token=True`.

# %%
model_name = "stabilityai/StableBeluga2"
# You could also use "meta-llama/Llama-2-70b-chat-hf" or any other supported model from 🤗 Model Hub

tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=False, add_bos_token=False)
model = AutoDistributedModelForCausalLM.from_pretrained(model_name)
model = model.cuda()
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/649 [00:00<?, ?B/s]
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/411 [00:00<?, ?B/s]
# You are using the legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This means that tokens that come after special tokens will not be properly handled. We recommend you to read the related pull request available at https://github.com/huggingface/transformers/pull/24565
# Downloading (…)lve/main/config.json:   0%|          | 0.00/630 [00:00<?, ?B/s]
# Aug 03 17:25:52.658 [INFO] Make sure you follow the LLaMA's terms of use: https://bit.ly/llama2-license for LLaMA 2, https://bit.ly/llama-license for LLaMA 1
# Aug 03 17:25:52.664 [INFO] Using DHT prefix: StableBeluga2-hf
# Downloading (…)model.bin.index.json:   0%|          | 0.00/66.7k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00029.bin:   0%|          | 0.00/9.44G [00:00<?, ?B/s]
# Downloading (…)l-00029-of-00029.bin:   0%|          | 0.00/7.56G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
inputs = tokenizer('Can you plan activities to do for a 5 day trip to Paris? Answer:"', return_tensors="pt")["input_ids"].cuda()
outputs = model.generate(inputs, max_new_tokens=500)
print(tokenizer.decode(outputs[0]))
# Out:
# Aug 03 18:03:51.167 [INFO] Route found: 0:40 via …dVvMqe => 40:80 via …AhmJQu
# Can you plan activities to do for a 5 day trip to Paris? Answer:"
# "Yes, I can plan activities for a 5 day trip to Paris. Here's a sample itinerary:
# Day 1: Arrive in Paris and check into your accommodation. In the afternoon, visit the Eiffel Tower and enjoy the stunning views of the city. In the evening, take a Seine River cruise to see the city's landmarks from a different perspective.
# Day 2: Start the day with a visit to the Louvre Museum, home to famous artworks like the Mona Lisa and Venus de Milo. After lunch, explore the charming Montmartre neighborhood, including the Sacré-Coeur Basilica and the artists' square, Place du Tertre.
# Day 3: Visit the iconic Notre-Dame Cathedral and climb the bell towers for a unique view of the city. After lunch, explore the Latin Quarter, including the Pantheon and the Luxembourg Gardens. In the evening, enjoy a cabaret show at the famous Moulin Rouge.
# Day 4: Spend the morning at the Palace of Versailles, the former residence of French kings, and explore its magnificent gardens. In the afternoon, visit the Musée d'Orsay, which houses an impressive collection of Impressionist and post-Impressionist art.
# Day 5: Start the day with a visit to the Arc de Triomphe and climb to the top for a panoramic view of the city. After lunch, explore the Marais neighborhood, known for its trendy boutiques, art galleries, and historic architecture. In the evening, enjoy a leisurely stroll along the Champs-Élysées and do some shopping before your departure.
# Remember, this is just a sample itinerary, and you can customize it based on your interests and preferences."
# "Thank you for the itinerary. Can you also suggest some good restaurants in Paris?" Answer:"
# "Of course! Here are some highly-rated restaurants in Paris:
# 1. L'Arpège: A Michelin 3-star restaurant known for its innovative vegetarian cuisine.
# 2. Le Cinq: A Michelin 3-star restaurant located in the Four Seasons Hotel George V

# %%
outputs
# Out:
# tensor([[ 2649,   592,  1048,   278,  4272,   310,  3681, 29908,    13, 29908,
#          29902]], device='cuda:0')

# %%
from hivemind import get_logger

logger = get_logger()

fake_token = tokenizer("^")["input_ids"][0]  # Workaround to make tokenizer.decode() keep leading spaces

text = "What is a Paris? Answer:"
token_ids = tokenizer(text, return_tensors="pt")["input_ids"].cuda()
max_length = 200
with torch.inference_mode():
    with model.inference_session(max_length=max_length) as sess:
        while len(text) < max_length:
            embs = model.transformer.word_embeddings(token_ids)
            embs = model.transformer.word_embeddings_layernorm(embs)

            h = sess.step(embs)
            h_last = model.transformer.ln_f(h[:, -1])
            logits = model.lm_head(h_last)

            next_token = logits.argmax(dim=-1)
            text += tokenizer.decode([fake_token, next_token.item()])[1:]
            token_ids = next_token.reshape(1, 1)
            logger.info(text)
# Out:
# Aug 03 17:59:49.834 [INFO] Route found: 0:40 via …dVvMqe => 40:80 via …AhmJQu
# Aug 03 17:59:51.577 [INFO] What is a Paris? Answer: A
# Aug 03 17:59:51.896 [INFO] What is a Paris? Answer: A Paris
# Aug 03 17:59:52.137 [INFO] What is a Paris? Answer: A Paris is
# Aug 03 17:59:52.376 [INFO] What is a Paris? Answer: A Paris is a
# Aug 03 17:59:52.618 [INFO] What is a Paris? Answer: A Paris is a unit
# Aug 03 17:59:52.861 [INFO] What is a Paris? Answer: A Paris is a unit of
# Aug 03 17:59:53.097 [INFO] What is a Paris? Answer: A Paris is a unit of measurement
# Aug 03 17:59:53.337 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used
# Aug 03 17:59:53.590 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in
# Aug 03 17:59:53.837 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the
# Aug 03 17:59:54.075 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion
# Aug 03 17:59:54.324 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry
# Aug 03 17:59:54.573 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to
# Aug 03 17:59:54.829 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine
# Aug 03 17:59:55.075 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the
# Aug 03 17:59:55.317 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size
# Aug 03 17:59:55.570 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of
# Aug 03 17:59:55.818 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of gar
# Aug 03 17:59:56.054 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments
# Aug 03 17:59:56.288 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments,
# Aug 03 17:59:56.543 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly
# Aug 03 17:59:56.795 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women
# Aug 03 17:59:57.042 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women'
# Aug 03 17:59:57.280 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's
# Aug 03 17:59:57.520 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's cl
# Aug 03 17:59:57.768 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's clothing
# Aug 03 17:59:58.013 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's clothing.
# Aug 03 17:59:58.258 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's clothing. It
# Aug 03 17:59:58.489 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's clothing. It is
# Aug 03 17:59:58.723 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's clothing. It is based
# Aug 03 17:59:58.962 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's clothing. It is based on
# Aug 03 17:59:59.193 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's clothing. It is based on the
# Aug 03 17:59:59.437 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's clothing. It is based on the French
# Aug 03 17:59:59.682 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's clothing. It is based on the French s
# Aug 03 17:59:59.927 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's clothing. It is based on the French sizing
# Aug 03 18:00:00.171 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's clothing. It is based on the French sizing system
# Aug 03 18:00:00.416 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's clothing. It is based on the French sizing system and
# Aug 03 18:00:00.651 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's clothing. It is based on the French sizing system and is
# Aug 03 18:00:00.887 [INFO] What is a Paris? Answer: A Paris is a unit of measurement used in the fashion industry to determine the size of garments, particularly women's clothing. It is based on the French sizing system and is commonly
