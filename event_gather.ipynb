# %% [markdown]
# <a href="https://colab.research.google.com/github/vyz1194/vyz/blob/master/event_gather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-search-results
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32003 sha256=bff257b01c2afd60e7630aae6c8b8ab2f683d61361f9a1e714343cc45b28cbfe
#   Stored in directory: /root/.cache/pip/wheels/d3/b2/c3/03302d12bb44a2cdff3c9371f31b72c0c4e84b8d2285eeac53
# Successfully built google-search-results
# ...

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_events",
  "q": "Events in Bangalore from september 25th to october 5th",
  "hl": "en",
  "gl": "us",
  "api_key": "6918ad985b2873f7ea1bf3ccaec6dd8371b2d8cda87e17f4e3c8ee718e76fc1b"
}

search = GoogleSearch(params)
results = search.get_dict()
events_results = results["events_results"]

# %%
events_results
# Out:
# [{'title': 'Armin van Buuren @ Bhartiya City',
#   'date': {'start_date': 'Oct 5', 'when': 'Thu, Oct 5, 2:30 PM'},
#   'address': ['Bhartiya City', 'Bengaluru, Karnataka, India'],
#   'link': 'https://www.bandsintown.com/e/1029439998-armin-van-buuren-at-bhartiya-city',
#   'event_location_map': {'image': 'https://www.google.com/maps/vt/data=UvQn1hostpWtttcYS9f26G5Ghyh1AWxf-3DXY_kKPzCHSqJdePUwXtBY30sjm29KBWl-nHAt_A',
#    'link': 'https://www.google.com/maps/place//data=!4m2!3m1!1s0x3bae19ed574b7d87:0xbdb4aa3eb1166f06?sa=X&ved=2ahUKEwjHp4fV54GBAxVGD1kFHcNlBLIQ9eIBegQIARAA&hl=en&gl=us',
#    'serpapi_link': 'https://serpapi.com/search.json?data=%214m2%213m1%211s0x3bae19ed574b7d87%3A0xbdb4aa3eb1166f06&engine=google_maps&google_domain=google.com&hl=en&q=Events+in+Bangalore+from+september+25th+to+october+5th&type=place'},
# ...

# %%
import pandas as pd

# %%
events=pd.DataFrame(events_results)

# %%
events
# Out:
#                                               title  \
# 0                  Armin van Buuren @ Bhartiya City
# 1    Sunburn Arena Ft. Armin van Buuren - Bengaluru
# 2            Ashwyn Singh and Daniel Fernandes Live
# 3                                       Trevor Noah
# 4            Capoeira Celebration in Bangalore City
# 5                                RAW COMEDY MONDAYS
# 6  Bengaluru Bookfair - LockTheBox at Nexus Mall...
# 7                         Bhoomi Yugaantar Festival
# 8            SIA Musical Fest - Urmi Live at Fandom
# 9                   MOUNT KILIMANJARO SUMMIT - 2023
#
#                                                 date  \
# 0  {'start_date': 'Oct 5', 'when': 'Thu, Oct 5, 2...
# 1  {'start_date': 'Oct 5', 'when': 'Thu, Oct 5, 9...
# 2  {'start_date': 'Oct 1', 'when': 'Sun, Oct 1, 1...
# 3  {'start_date': 'Sep 27', 'when': 'Wed, Sep 27,...
# 4  {'start_date': 'Sep 30', 'when': 'Sat, Sep 30,...
# 5  {'start_date': 'Aug 29', 'when': 'Aug 29, 1:30...
# ...
